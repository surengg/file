# %%
import matplotlib.pyplot as plt
import pandas
from sklearn import tree
from sklearn.tree import Decision TreeClassifier
import matplotlib.pyplot as plt
df = pandas.read_csv("C:\decision_tree.csv")
print(df)

d=['UK': 0, 'USA': 1, 'N': 2]
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)
features = ['Age', 'Experience', 'Rank', 'Nationality']

X = df[features]
y = df['Go']
dtree = Decision Tree Classifier()
dtreedtree.fit(X, y)
               
tree.plot_tree(dtree, feature_names=features)

plt.show()

# %%
# Out:
# Axes(0.125,0.11;0.775x0.77)
# None

# %%
sns.lineplot(data=y)
plt.show()

# %%
sns.scatterplot(data=y)
plt.show()

# %%
sns.barplot(data=y)
plt.show()

# %%
y1=np.array([[1,3,4,5],[2,5,9,2],[2,5,8,11],[1,2,5,12]])
sns.heatmap(data=y1) #heatmap
plt.show()

# %%
sns.boxplot(data=y1) #boxplot having median,quartiles and outliers in data
plt.show()
